# %% [markdown]
# # Ejercicio 03: Cálculo de Relevancia y Ranking de Documentos
#
#
#
# El objetivo de este ejercicio es calcular analíticamente la relevancia de cada documento en un corpus y luego ordenar (rankear) los documentos basándonos en esa puntuación de relevancia para tres consultas específicas. Seguirás los siguientes pasos:

# %% [markdown]
# Integrantes: Vickiann Jimenez, Gabriela Salazar, Jostin Vega

# %% [markdown]
# Descripción del Ejercicio
#
#
#
# 1. Procesamiento del Corpus:
#
#     * Leer y parsear el archivo XML proporcionado que contiene el corpus de documentos con sus metadatos (keywords, autor y fecha).

# %%
# Importar las librerías necesarias

import xml.etree.ElementTree as ET
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import re



# Definir las consultas

queries = {

    1: "Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios",

    2: "Actividades extracurriculares y bienestar emocional en el campus universitario",

    3: "Estrategias universitarias para reducir el estrés en estudiantes"

}



# Función para procesar el texto y extraer palabras clave

def process_text(text):

    # Convertir a minúsculas

    text = text.lower()

    # Reemplazar caracteres no alfanuméricos por espacios

    import re

    text = re.sub(r'[^a-záéíóúñü]+', ' ', text)

    # Tokenizar y eliminar palabras vacías si es necesario

    tokens = text.strip().split()

    return set(tokens)



# Paso 1: Leer y parsear el archivo XML

def parse_corpus(xml_file):

    tree = ET.parse(xml_file)

    root = tree.getroot()

    corpus = {}

    for doc in root.findall('document'):

        doc_id = int(doc.get('id'))

        title = doc.find('title').text

        keywords = doc.find('keywords').text

        author = doc.find('author').text

        date = doc.find('date').text

        # Procesar las palabras clave

        keyword_set = process_text(keywords)

        corpus[doc_id] = {

            'title': title,

            'keywords': keyword_set,

            'author': author,

            'date': date

        }

    return corpus

# %%
corpus = parse_corpus('03ranking_corpus.xml')

corpus
# Out:
# {1: {'title': 'El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.',
#   'keywords': {'crónica',
#    'médica',
#    'salud',
#    'tecnología',
#    'telemedicina',
#    'tratamiento'},
#   'author': 'Dr. Juan Pérez',
#   'date': '2023-01-15'},
#  2: {'title': 'Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.',
#   'keywords': {'académico',
#    'estudiantes',
#    'mental',
#    'nutrición',
#    'rendimiento',
#    'salud'},
#   'author': 'Dra. María López',
#   'date': '2023-02-10'},
#  3: {'title': 'Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.',
#   'keywords': {'amistad',
#    'bienestar',
#    'campus',
#    'estudiantil',
#    'relaciones',
#    'sociales'},
#   'author': 'Miguel Rodríguez',
#   'date': '2023-03-05'},
#  4: {'title': 'El rol de las bibliotecas universitarias en el fomento de la investigación académica.',
#   'keywords': {'academia',
#    'bibliotecas',
#    'investigación',
#    'recursos',
#    'universitarias'},
#   'author': 'Lucía Martínez',
#   'date': '2023-04-20'},
#  5: {'title': 'Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.',
#   'keywords': {'campus',
#    'concentración',
#    'espacios',
#    'estrés',
#    'universitario',
#    'verdes'},
#   'author': 'Carlos Fernández',
#   'date': '2023-05-15'},
#  6: {'title': 'La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.',
#   'keywords': {'bienestar',
#    'cultura',
#    'estudiantes',
#    'hábitos',
#    'saludables',
#    'universitaria'},
#   'author': 'Ana Sánchez',
#   'date': '2023-06-10'},
#  7: {'title': 'La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.',
#   'keywords': {'académico',
#    'mental',
#    'rendimiento',
#    'salud',
#    'sueño',
#    'universitarios'},
#   'author': 'Javier Torres',
#   'date': '2023-07-25'},
#  8: {'title': 'La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.',
#   'keywords': {'apoyo',
#    'bienestar',
#    'emocional',
#    'estudiantes',
#    'familiar',
#    'social'},
#   'author': 'Laura Gómez',
#   'date': '2023-08-30'},
#  9: {'title': 'El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.',
#   'keywords': {'adultos',
#    'cognitivo',
#    'de',
#    'desarrollo',
#    'hábitos',
#    'jóvenes',
#    'lectura'},
#   'author': 'Fernando Ruiz',
#   'date': '2023-09-18'},
#  10: {'title': 'Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.',
#   'keywords': {'avances',
#    'jóvenes',
#    'medicina',
#    'médica',
#    'preventiva',
#    'tecnología',
#    'tecnológicos'},
#   'author': 'Elena Navarro',
#   'date': '2023-10-05'},
#  11: {'title': 'Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.',
#   'keywords': {'académico',
#    'ejercicio',
#    'estrés',
#    'estudiantes',
#    'salud',
#    'universitarios'},
#   'author': 'Diego Castro',
#   'date': '2023-11-12'},
#  12: {'title': 'El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.',
#   'keywords': {'ansiedad',
#    'estudiantes',
#    'meditación',
#    'mindfulness',
#    'universitarios'},
#   'author': 'Sofía Vega',
#   'date': '2023-12-01'},
#  13: {'title': 'Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.',
#   'keywords': {'apoyo',
#    'de',
#    'estudiantes',
#    'estudio',
#    'grupos',
#    'mental',
#    'psicológico',
#    'salud',
#    'universitarios'},
#   'author': 'Marcos Ortiz',
#   'date': '2024-01-10'},
#  14: {'title': 'Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.',
#   'keywords': {'académico',
#    'desempeño',
#    'estudiantes',
#    'mental',
#    'salud',
#    'servicios',
#    'universitarios'},
#   'author': 'Paula Morales',
#   'date': '2024-02-15'},
#  15: {'title': 'Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.',
#   'keywords': {'actividades',
#    'bienestar',
#    'emocional',
#    'estudiantes',
#    'extracurriculares',
#    'social'},
#   'author': 'José Herrera',
#   'date': '2024-03-05'},
#  16: {'title': 'El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.',
#   'keywords': {'competencias',
#    'de',
#    'desarrollo',
#    'educación',
#    'innovación',
#    'laboratorios',
#    'tecnológicas'},
#   'author': 'Andrea Díaz',
#   'date': '2024-04-20'},
#  17: {'title': 'Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.',
#   'keywords': {'campus',
#    'colaboración',
#    'de',
#    'diseño',
#    'interacción',
#    'tendencias'},
#   'author': 'Sergio Muñoz',
#   'date': '2024-05-15'},
#  18: {'title': 'Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.',
#   'keywords': {'académico',
#    'bienestar',
#    'comparación',
#    'estudiantes',
#    'que',
#    'rendimiento',
#    'trabajan'},
#   'author': 'Isabel Flores',
#   'date': '2024-06-10'},
#  19: {'title': 'Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.',
#   'keywords': {'académico',
#    'agotamiento',
#    'de',
#    'estudiantes',
#    'factores',
#    'prevención',
#    'riesgo',
#    'universitarios'},
#   'author': 'Ricardo Ramos',
#   'date': '2024-07-25'},
#  20: {'title': 'El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.',
#   'keywords': {'calidad',
#    'del',
#    'estudiantes',
#    'redes',
#    'sociales',
#    'sueño',
#    'tecnología'},
#   'author': 'Valeria Castillo',
#   'date': '2024-08-30'},
#  21: {'title': 'Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.',
#   'keywords': {'ambiental',
#    'edificios',
#    'impacto',
#    'sostenibilidad',
#    'tecnologías',
#    'universitarios',
#    'verdes'},
#   'author': 'Daniel Medina',
#   'date': '2024-09-18'},
#  22: {'title': 'Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.',
#   'keywords': {'bicicletas',
#    'compartidas',
#    'movilidad',
#    'sostenible',
#    'transporte',
#    'universidades'},
#   'author': 'Patricia Reyes',
#   'date': '2024-10-05'},
#  23: {'title': 'Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.',
#   'keywords': {'académica',
#    'apoyo',
#    'carga',
#    'emocional',
#    'estudiantes',
#    'salud',
#    'universitario'},
#   'author': 'Gonzalo Soto',
#   'date': '2024-11-12'},
#  24: {'title': 'Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.',
#   'keywords': {'académica',
#    'equilibrio',
#    'estrategias',
#    'estudiantes',
#    'social',
#    'vida'},
#   'author': 'Camila Aguilar',
#   'date': '2024-12-01'},
#  25: {'title': 'La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.',
#   'keywords': {'actividades',
#    'artísticas',
#    'bienestar',
#    'creatividad',
#    'psicológico',
#    'universitaria',
#    'vida'},
#   'author': 'Adrián Vargas',
#   'date': '2025-01-10'},
#  26: {'title': 'Los beneficios de los programas de becas para la retención de estudiantes en universidades.',
#   'keywords': {'becas',
#    'beneficios',
#    'de',
#    'estudiantes',
#    'programas',
#    'retención',
#    'universidades'},
#   'author': 'Teresa Romero',
#   'date': '2025-02-15'},
#  27: {'title': 'El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.',
#   'keywords': {'actividad',
#    'deportes',
#    'estudiantes',
#    'física',
#    'integración',
#    'social'},
#   'author': 'Alberto Peña',
#   'date': '2025-03-05'},
#  28: {'title': 'Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.',
#   'keywords': {'bienestar',
#    'de',
#    'del',
#    'estrés',
#    'eventos',
#    'reducción',
#    'talleres',
#    'universidad'},
#   'author': 'Silvia Campos',
#   'date': '2025-04-20'},
#  29: {'title': 'Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.',
#   'keywords': {'análisis',
#    'de',
#    'en',
#    'estudiantes',
#    'exámenes',
#    'hábitos',
#    'rendimiento',
#    'sueño'},
#   'author': 'Óscar Luna',
#   'date': '2025-05-15'},
#  30: {'title': 'Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.',
#   'keywords': {'artificial',
#    'comunidades',
#    'inteligencia',
#    'médicos',
#    'remotas',
#    'servicios',
#    'tecnología'},
#   'author': 'María Paredes',
#   'date': '2025-06-10'}}

# %% [markdown]
# 2. Procesamiento de las Consultas:
#
#     * Definir las consultas proporcionadas.
#
#     * Extraer las palabras clave de cada consulta.

# %%
# Paso 2: Procesamiento de las Consultas
def process_queries(queries):
    processed_queries = {}
    for q_id, query in queries.items():
        processed_queries[q_id] = process_text(query)
    return processed_queries

# Procesar las consultas 
processed_queries = process_queries(queries)
print("\nConsultas:")
for q_id, keywords in processed_queries.items():
    print(f"Consulta {q_id}: {keywords}")
# Out:
# Consultas:
# Consulta 1: {'universitarios', 'estudiantes', 'la', 'rendimiento', 'el', 'de', 'en', 'los', 'académico', 'impacto', 'salud', 'mental'}
# Consulta 2: {'extracurriculares', 'el', 'emocional', 'en', 'actividades', 'campus', 'universitario', 'y', 'bienestar'}
# Consulta 3: {'estrés', 'estudiantes', 'reducir', 'el', 'en', 'estrategias', 'universitarias', 'para'}

# %% [markdown]
# 3. Cálculo de Relevancia:
#
#     * Utilizar métricas de similitud (Similitud Coseno y Jaccard) entre la representación vectorial de los documentos y las de las consultas.
#
#     * Calcular la puntuación de relevancia para cada documento del corpus respecto a cada consulta.

# %%
# Función de Similitud de Jaccard
def jaccard_similarity(set1, set2):
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    return len(intersection) / len(union) if union else 0

# Función de Similitud Coseno
def cosine_similarity(set1, set2):
    all_terms = list(set1.union(set2))
    vec1 = np.array([1 if term in set1 else 0 for term in all_terms])
    vec2 = np.array([1 if term in set2 else 0 for term in all_terms])
    dot_product = np.dot(vec1, vec2)
    magnitude = np.sqrt(np.dot(vec1, vec1)) * np.sqrt(np.dot(vec2, vec2))
    return dot_product / magnitude if magnitude else 0

# Paso 3: Calcular la relevancia entre cada consulta y cada documento
def calculate_relevance(corpus, queries):
    relevance_scores = {}
    for q_id, query_keywords in queries.items():
        relevance_scores[q_id] = {}
        for doc_id, doc_data in corpus.items():
            jaccard_score = jaccard_similarity(query_keywords, doc_data['keywords'])
            cosine_score = cosine_similarity(query_keywords, doc_data['keywords'])
            relevance_scores[q_id][doc_id] = {
                'jaccard': jaccard_score,
                'cosine': cosine_score
            }
    return relevance_scores

# Calcular las puntuaciones de relevancia
relevance_scores = calculate_relevance(corpus, processed_queries)
print("\nPuntuaciones de Relevancia (Similitud Jaccard y Coseno):")
for q_id, scores in relevance_scores.items():
    print(f"\nConsulta {q_id}:")
    for doc_id, score in scores.items():
        print(f"  Documento {doc_id}: Jaccard = {score['jaccard']:.4f}, Coseno = {score['cosine']:.4f}")
# Out:
# Puntuaciones de Relevancia (Similitud Jaccard y Coseno):
#
# Consulta 1:
#   Documento 1: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 2: Jaccard = 0.3846, Coseno = 0.5893
#   Documento 3: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 4: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 5: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 6: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 7: Jaccard = 0.3846, Coseno = 0.5893
#   Documento 8: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 9: Jaccard = 0.0556, Coseno = 0.1091
#   Documento 10: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 11: Jaccard = 0.2857, Coseno = 0.4714
#   Documento 12: Jaccard = 0.1333, Coseno = 0.2582
#   Documento 13: Jaccard = 0.3125, Coseno = 0.4811
#   Documento 14: Jaccard = 0.3571, Coseno = 0.5455
#   Documento 15: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 16: Jaccard = 0.0556, Coseno = 0.1091
#   Documento 17: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 18: Jaccard = 0.1875, Coseno = 0.3273
#   Documento 19: Jaccard = 0.2500, Coseno = 0.4082
#   Documento 20: Jaccard = 0.0556, Coseno = 0.1091
#   Documento 21: Jaccard = 0.1176, Coseno = 0.2182
#   Documento 22: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 23: Jaccard = 0.1176, Coseno = 0.2182
#   Documento 24: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 25: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 26: Jaccard = 0.1176, Coseno = 0.2182
#   Documento 27: Jaccard = 0.0588, Coseno = 0.1179
#   Documento 28: Jaccard = 0.0526, Coseno = 0.1021
#   Documento 29: Jaccard = 0.2500, Coseno = 0.4082
#   Documento 30: Jaccard = 0.0000, Coseno = 0.0000
#
# Consulta 2:
#   Documento 1: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 2: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 3: Jaccard = 0.1538, Coseno = 0.2722
#   Documento 4: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 5: Jaccard = 0.1538, Coseno = 0.2722
#   Documento 6: Jaccard = 0.0714, Coseno = 0.1361
#   Documento 7: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 8: Jaccard = 0.1538, Coseno = 0.2722
#   Documento 9: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 10: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 11: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 12: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 13: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 14: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 15: Jaccard = 0.3636, Coseno = 0.5443
#   Documento 16: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 17: Jaccard = 0.0714, Coseno = 0.1361
#   Documento 18: Jaccard = 0.0667, Coseno = 0.1260
#   Documento 19: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 20: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 21: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 22: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 23: Jaccard = 0.1429, Coseno = 0.2520
#   Documento 24: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 25: Jaccard = 0.1429, Coseno = 0.2520
#   Documento 26: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 27: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 28: Jaccard = 0.0625, Coseno = 0.1179
#   Documento 29: Jaccard = 0.0625, Coseno = 0.1179
#   Documento 30: Jaccard = 0.0000, Coseno = 0.0000
#
# Consulta 3:
#   Documento 1: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 2: Jaccard = 0.0769, Coseno = 0.1443
#   Documento 3: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 4: Jaccard = 0.0833, Coseno = 0.1581
#   Documento 5: Jaccard = 0.0769, Coseno = 0.1443
#   Documento 6: Jaccard = 0.0769, Coseno = 0.1443
#   Documento 7: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 8: Jaccard = 0.0769, Coseno = 0.1443
#   Documento 9: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 10: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 11: Jaccard = 0.1667, Coseno = 0.2887
#   Documento 12: Jaccard = 0.0833, Coseno = 0.1581
#   Documento 13: Jaccard = 0.0625, Coseno = 0.1179
#   Documento 14: Jaccard = 0.0714, Coseno = 0.1336
#   Documento 15: Jaccard = 0.0769, Coseno = 0.1443
#   Documento 16: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 17: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 18: Jaccard = 0.0714, Coseno = 0.1336
#   Documento 19: Jaccard = 0.0667, Coseno = 0.1250
#   Documento 20: Jaccard = 0.0714, Coseno = 0.1336
#   Documento 21: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 22: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 23: Jaccard = 0.0714, Coseno = 0.1336
#   Documento 24: Jaccard = 0.1667, Coseno = 0.2887
#   Documento 25: Jaccard = 0.0000, Coseno = 0.0000
#   Documento 26: Jaccard = 0.0714, Coseno = 0.1336
#   Documento 27: Jaccard = 0.0769, Coseno = 0.1443
#   Documento 28: Jaccard = 0.0667, Coseno = 0.1250
#   Documento 29: Jaccard = 0.1429, Coseno = 0.2500
#   Documento 30: Jaccard = 0.0000, Coseno = 0.0000

# %% [markdown]
# 4. Ranking de Documentos:
#
#     * Ordenar los documentos en función de su puntuación de relevancia de mayor a menor.
#
#     * Mostrar el ranking de documentos para cada consulta.

# %%
# Paso 4: Crear el ranking basado en la relevancia
def rank_documents(relevance_scores, metric='cosine'):
    ranked_results = {}
    for q_id, scores in relevance_scores.items():
        ranked_results[q_id] = sorted(scores.items(), key=lambda item: item[1][metric], reverse=True)
    return ranked_results

# Generar y mostrar el ranking de documentos para cada consulta
ranked_results_jaccard = rank_documents(relevance_scores, metric='jaccard')
ranked_results_cosine = rank_documents(relevance_scores, metric='cosine')

for q_id in queries:
    print(f"\nConsulta {q_id}: {queries[q_id]}")
    print("Ranking (Similitud Jaccard):")
    for doc_id, score in ranked_results_jaccard[q_id]:
        print(f"  Documento {doc_id}: Puntuación de Jaccard = {score['jaccard']:.4f}")
    
    print("\nRanking (Similitud Coseno):")
    for doc_id, score in ranked_results_cosine[q_id]:
        print(f"  Documento {doc_id}: Puntuación de Coseno = {score['cosine']:.4f}")
# Out:
# Consulta 1: Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios
# Ranking (Similitud Jaccard):
#   Documento 2: Puntuación de Jaccard = 0.3846
#   Documento 7: Puntuación de Jaccard = 0.3846
#   Documento 14: Puntuación de Jaccard = 0.3571
#   Documento 13: Puntuación de Jaccard = 0.3125
#   Documento 11: Puntuación de Jaccard = 0.2857
#   Documento 19: Puntuación de Jaccard = 0.2500
#   Documento 29: Puntuación de Jaccard = 0.2500
#   Documento 18: Puntuación de Jaccard = 0.1875
#   Documento 12: Puntuación de Jaccard = 0.1333
#   Documento 21: Puntuación de Jaccard = 0.1176
#   Documento 23: Puntuación de Jaccard = 0.1176
#   Documento 26: Puntuación de Jaccard = 0.1176
#   Documento 1: Puntuación de Jaccard = 0.0588
#   Documento 6: Puntuación de Jaccard = 0.0588
#   Documento 8: Puntuación de Jaccard = 0.0588
#   Documento 15: Puntuación de Jaccard = 0.0588
#   Documento 17: Puntuación de Jaccard = 0.0588
#   Documento 24: Puntuación de Jaccard = 0.0588
#   Documento 27: Puntuación de Jaccard = 0.0588
#   Documento 9: Puntuación de Jaccard = 0.0556
#   Documento 16: Puntuación de Jaccard = 0.0556
#   Documento 20: Puntuación de Jaccard = 0.0556
#   Documento 28: Puntuación de Jaccard = 0.0526
#   Documento 3: Puntuación de Jaccard = 0.0000
#   Documento 4: Puntuación de Jaccard = 0.0000
#   Documento 5: Puntuación de Jaccard = 0.0000
#   Documento 10: Puntuación de Jaccard = 0.0000
#   Documento 22: Puntuación de Jaccard = 0.0000
#   Documento 25: Puntuación de Jaccard = 0.0000
#   Documento 30: Puntuación de Jaccard = 0.0000
#
# Ranking (Similitud Coseno):
#   Documento 2: Puntuación de Coseno = 0.5893
#   Documento 7: Puntuación de Coseno = 0.5893
#   Documento 14: Puntuación de Coseno = 0.5455
#   Documento 13: Puntuación de Coseno = 0.4811
#   Documento 11: Puntuación de Coseno = 0.4714
#   Documento 19: Puntuación de Coseno = 0.4082
#   Documento 29: Puntuación de Coseno = 0.4082
#   Documento 18: Puntuación de Coseno = 0.3273
#   Documento 12: Puntuación de Coseno = 0.2582
#   Documento 21: Puntuación de Coseno = 0.2182
#   Documento 23: Puntuación de Coseno = 0.2182
#   Documento 26: Puntuación de Coseno = 0.2182
#   Documento 1: Puntuación de Coseno = 0.1179
#   Documento 6: Puntuación de Coseno = 0.1179
#   Documento 8: Puntuación de Coseno = 0.1179
#   Documento 15: Puntuación de Coseno = 0.1179
#   Documento 17: Puntuación de Coseno = 0.1179
#   Documento 24: Puntuación de Coseno = 0.1179
#   Documento 27: Puntuación de Coseno = 0.1179
#   Documento 9: Puntuación de Coseno = 0.1091
#   Documento 16: Puntuación de Coseno = 0.1091
#   Documento 20: Puntuación de Coseno = 0.1091
#   Documento 28: Puntuación de Coseno = 0.1021
#   Documento 3: Puntuación de Coseno = 0.0000
#   Documento 4: Puntuación de Coseno = 0.0000
#   Documento 5: Puntuación de Coseno = 0.0000
#   Documento 10: Puntuación de Coseno = 0.0000
#   Documento 22: Puntuación de Coseno = 0.0000
#   Documento 25: Puntuación de Coseno = 0.0000
#   Documento 30: Puntuación de Coseno = 0.0000
#
# Consulta 2: Actividades extracurriculares y bienestar emocional en el campus universitario
# Ranking (Similitud Jaccard):
#   Documento 15: Puntuación de Jaccard = 0.3636
#   Documento 3: Puntuación de Jaccard = 0.1538
#   Documento 5: Puntuación de Jaccard = 0.1538
#   Documento 8: Puntuación de Jaccard = 0.1538
#   Documento 23: Puntuación de Jaccard = 0.1429
#   Documento 25: Puntuación de Jaccard = 0.1429
#   Documento 6: Puntuación de Jaccard = 0.0714
#   Documento 17: Puntuación de Jaccard = 0.0714
#   Documento 18: Puntuación de Jaccard = 0.0667
#   Documento 28: Puntuación de Jaccard = 0.0625
#   Documento 29: Puntuación de Jaccard = 0.0625
#   Documento 1: Puntuación de Jaccard = 0.0000
#   Documento 2: Puntuación de Jaccard = 0.0000
#   Documento 4: Puntuación de Jaccard = 0.0000
#   Documento 7: Puntuación de Jaccard = 0.0000
#   Documento 9: Puntuación de Jaccard = 0.0000
#   Documento 10: Puntuación de Jaccard = 0.0000
#   Documento 11: Puntuación de Jaccard = 0.0000
#   Documento 12: Puntuación de Jaccard = 0.0000
#   Documento 13: Puntuación de Jaccard = 0.0000
#   Documento 14: Puntuación de Jaccard = 0.0000
#   Documento 16: Puntuación de Jaccard = 0.0000
#   Documento 19: Puntuación de Jaccard = 0.0000
#   Documento 20: Puntuación de Jaccard = 0.0000
#   Documento 21: Puntuación de Jaccard = 0.0000
#   Documento 22: Puntuación de Jaccard = 0.0000
#   Documento 24: Puntuación de Jaccard = 0.0000
#   Documento 26: Puntuación de Jaccard = 0.0000
#   Documento 27: Puntuación de Jaccard = 0.0000
#   Documento 30: Puntuación de Jaccard = 0.0000
#
# Ranking (Similitud Coseno):
#   Documento 15: Puntuación de Coseno = 0.5443
#   Documento 3: Puntuación de Coseno = 0.2722
#   Documento 5: Puntuación de Coseno = 0.2722
#   Documento 8: Puntuación de Coseno = 0.2722
#   Documento 23: Puntuación de Coseno = 0.2520
#   Documento 25: Puntuación de Coseno = 0.2520
#   Documento 6: Puntuación de Coseno = 0.1361
#   Documento 17: Puntuación de Coseno = 0.1361
#   Documento 18: Puntuación de Coseno = 0.1260
#   Documento 28: Puntuación de Coseno = 0.1179
#   Documento 29: Puntuación de Coseno = 0.1179
#   Documento 1: Puntuación de Coseno = 0.0000
#   Documento 2: Puntuación de Coseno = 0.0000
#   Documento 4: Puntuación de Coseno = 0.0000
#   Documento 7: Puntuación de Coseno = 0.0000
#   Documento 9: Puntuación de Coseno = 0.0000
#   Documento 10: Puntuación de Coseno = 0.0000
#   Documento 11: Puntuación de Coseno = 0.0000
#   Documento 12: Puntuación de Coseno = 0.0000
#   Documento 13: Puntuación de Coseno = 0.0000
#   Documento 14: Puntuación de Coseno = 0.0000
#   Documento 16: Puntuación de Coseno = 0.0000
#   Documento 19: Puntuación de Coseno = 0.0000
#   Documento 20: Puntuación de Coseno = 0.0000
#   Documento 21: Puntuación de Coseno = 0.0000
#   Documento 22: Puntuación de Coseno = 0.0000
#   Documento 24: Puntuación de Coseno = 0.0000
#   Documento 26: Puntuación de Coseno = 0.0000
#   Documento 27: Puntuación de Coseno = 0.0000
#   Documento 30: Puntuación de Coseno = 0.0000
#
# Consulta 3: Estrategias universitarias para reducir el estrés en estudiantes
# Ranking (Similitud Jaccard):
#   Documento 11: Puntuación de Jaccard = 0.1667
#   Documento 24: Puntuación de Jaccard = 0.1667
#   Documento 29: Puntuación de Jaccard = 0.1429
#   Documento 4: Puntuación de Jaccard = 0.0833
#   Documento 12: Puntuación de Jaccard = 0.0833
#   Documento 2: Puntuación de Jaccard = 0.0769
#   Documento 5: Puntuación de Jaccard = 0.0769
#   Documento 6: Puntuación de Jaccard = 0.0769
#   Documento 8: Puntuación de Jaccard = 0.0769
#   Documento 15: Puntuación de Jaccard = 0.0769
#   Documento 27: Puntuación de Jaccard = 0.0769
#   Documento 14: Puntuación de Jaccard = 0.0714
#   Documento 18: Puntuación de Jaccard = 0.0714
#   Documento 20: Puntuación de Jaccard = 0.0714
#   Documento 23: Puntuación de Jaccard = 0.0714
#   Documento 26: Puntuación de Jaccard = 0.0714
#   Documento 19: Puntuación de Jaccard = 0.0667
#   Documento 28: Puntuación de Jaccard = 0.0667
#   Documento 13: Puntuación de Jaccard = 0.0625
#   Documento 1: Puntuación de Jaccard = 0.0000
#   Documento 3: Puntuación de Jaccard = 0.0000
#   Documento 7: Puntuación de Jaccard = 0.0000
#   Documento 9: Puntuación de Jaccard = 0.0000
#   Documento 10: Puntuación de Jaccard = 0.0000
#   Documento 16: Puntuación de Jaccard = 0.0000
#   Documento 17: Puntuación de Jaccard = 0.0000
#   Documento 21: Puntuación de Jaccard = 0.0000
#   Documento 22: Puntuación de Jaccard = 0.0000
#   Documento 25: Puntuación de Jaccard = 0.0000
#   Documento 30: Puntuación de Jaccard = 0.0000
#
# Ranking (Similitud Coseno):
#   Documento 11: Puntuación de Coseno = 0.2887
#   Documento 24: Puntuación de Coseno = 0.2887
#   Documento 29: Puntuación de Coseno = 0.2500
#   Documento 4: Puntuación de Coseno = 0.1581
#   Documento 12: Puntuación de Coseno = 0.1581
#   Documento 2: Puntuación de Coseno = 0.1443
#   Documento 5: Puntuación de Coseno = 0.1443
#   Documento 6: Puntuación de Coseno = 0.1443
#   Documento 8: Puntuación de Coseno = 0.1443
#   Documento 15: Puntuación de Coseno = 0.1443
#   Documento 27: Puntuación de Coseno = 0.1443
#   Documento 14: Puntuación de Coseno = 0.1336
#   Documento 18: Puntuación de Coseno = 0.1336
#   Documento 20: Puntuación de Coseno = 0.1336
#   Documento 23: Puntuación de Coseno = 0.1336
#   Documento 26: Puntuación de Coseno = 0.1336
#   Documento 19: Puntuación de Coseno = 0.1250
#   Documento 28: Puntuación de Coseno = 0.1250
#   Documento 13: Puntuación de Coseno = 0.1179
#   Documento 1: Puntuación de Coseno = 0.0000
#   Documento 3: Puntuación de Coseno = 0.0000
#   Documento 7: Puntuación de Coseno = 0.0000
#   Documento 9: Puntuación de Coseno = 0.0000
#   Documento 10: Puntuación de Coseno = 0.0000
#   Documento 16: Puntuación de Coseno = 0.0000
#   Documento 17: Puntuación de Coseno = 0.0000
#   Documento 21: Puntuación de Coseno = 0.0000
#   Documento 22: Puntuación de Coseno = 0.0000
#   Documento 25: Puntuación de Coseno = 0.0000
#   Documento 30: Puntuación de Coseno = 0.0000
